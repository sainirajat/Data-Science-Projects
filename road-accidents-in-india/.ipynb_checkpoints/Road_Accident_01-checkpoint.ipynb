# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('./only_road_accidents_data_month2.csv')

# %%
print df[:5]
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL  MAY  JUNE  JULY  \
# 0  A & N Islands  2001        8        23     15     15   14    19    14
# 1  A & N Islands  2002       12        10     14     16   10     7    16
# 2  A & N Islands  2003       19        13     15     13   13    12     8
# 3  A & N Islands  2004       21        14     22     17   13    18    16
# 4  A & N Islands  2005       19        21     22     17   13    19    21
#
#    AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 0      19          7       12        13        22    181
# 1      11         23       21        11        17    168
# 2      16         17       25        14        15    180
# 3      19         16       20        15        24    215
# 4      14         15       19        10        16    206

# %%
print df.shape
# Out:
# (490, 15)

# %%
df = np.array(df)
print type(df)
# Out:
# <type 'numpy.ndarray'>

# %%
print type(df[0][1])
print df[1][1]
# Out:
# <type 'int'>
# 2002
# lala

# %%
year_2001 = {}
year_2002 = {}
year_2003 = {}
year_2004 = {}
year_2005 = {}
year_2006 = {}
year_2007 = {}
year_2008 = {}
year_2009 = {}
year_2010 = {}
year_2011 = {}
year_2012 = {}
year_2013 = {}
year_2014 = {}


# for year 2001
for ix in range(df.shape[0]):
    if df[ix][1] == 2001:
        year_2001[df[ix][0]] = df[ix][14]

# %%
num = 0
for ix in year_2001:
    print num," ",ix,"\t",year_2001[ix]
    num=num+1
# Out:
# 0   Haryana 	6373
# 1   Punjab 	1808
# 2   Goa 	1375
# 3   Chhattisgarh 	4987
# 4   Kerala 	36439
# 5   Bihar 	4334
# 6   Assam 	1806
# 7   Chandigarh 	493
# 8   Jharkhand 	995
# 9   Meghalaya 	161
# 10   Daman & Diu 	35
# 11   Madhya Pradesh 	19712
# 12   Lakshadweep 	6
# 13   Manipur 	410
# 14   Rajasthan 	19999
# 15   D & N Haveli 	87
# 16   A & N Islands 	181
# 17   West Bengal 	11430
# 18   Andhra Pradesh 	27188
# 19   Uttar Pradesh 	17921
# 20   Himachal Pradesh 	2110
# 21   Nagaland 	60
# 22   Gujarat 	19808
# 23   Tamil Nadu 	51978
# 24   Arunachal Pradesh 	236
# 25   Maharashtra 	37269
# 26   Tripura 	544
# 27   Uttarakhand 	1003
# 28   Puducherry 	1286
# 29   Karnataka 	32860
# 30   Jammu & Kashmir 	5011
# 31   Mizoram 	72
# 32   Delhi (Ut) 	9282
# 33   Odisha 	6406
# 34   Sikkim 	55

# %%
#for 2002
for ix in range(df.shape[0]):
    if df[ix][1] == 2002:
        year_2002[df[ix][0]] = df[ix][14]
#for 2003
for ix in range(df.shape[0]):
    if df[ix][1] == 2003:
        year_2003[df[ix][0]] = df[ix][14]
#for 2004        
for ix in range(df.shape[0]):
    if df[ix][1] == 2004:
        year_2004[df[ix][0]] = df[ix][14]
#for 2005        
for ix in range(df.shape[0]):
    if df[ix][1] == 2005:
        year_2005[df[ix][0]] = df[ix][14]
#for 2006
for ix in range(df.shape[0]):
    if df[ix][1] == 2006:
        year_2006[df[ix][0]] = df[ix][14]
        
#for 2007
for ix in range(df.shape[0]):
    if df[ix][1] == 2007:
        year_2007[df[ix][0]] = df[ix][14]
        
#for 2008
for ix in range(df.shape[0]):
    if df[ix][1] == 2008:
        year_2008[df[ix][0]] = df[ix][14]
        
# for 2009
for ix in range(df.shape[0]):
    if df[ix][1] == 2009:
        year_2009[df[ix][0]] = df[ix][14]
#for 2010
for ix in range(df.shape[0]):
    if df[ix][1] == 2010:
        year_2010[df[ix][0]] = df[ix][14]
#for 2011
for ix in range(df.shape[0]):
    if df[ix][1] == 2011:
        year_2011[df[ix][0]] = df[ix][14]
#for 2012
for ix in range(df.shape[0]):
    if df[ix][1] == 2012:
        year_2012[df[ix][0]] = df[ix][14]
#for 2013
for ix in range(df.shape[0]):
    if df[ix][1] == 2013:
        year_2013[df[ix][0]] = df[ix][14]
#for 2014
for ix in range(df.shape[0]):
    if df[ix][1] == 2014:
        year_2014[df[ix][0]] = df[ix][14]

# %%
#checking for errors
print year_2001['Haryana']
print year_2002['Haryana']
print year_2003['Haryana']
print year_2004['Haryana']
print year_2005['Haryana']
print year_2006['Haryana']
print year_2007['Haryana']
print year_2008['Haryana']
print year_2009['Haryana']
print year_2010['Haryana']
print year_2011['Haryana']
print year_2012['Haryana']
print year_2013['Haryana']
print year_2014['Haryana']
# Out:
# 6373
# 7087
# 6424
# 7908
# 7682
# 10262
# 10316
# 11241
# 11427
# 11161
# 10553
# 9971
# 10473
# 11043

# %%
labels = []
sizes = []
for ix in year_2001:
    labels.append(ix)
    sizes.append(year_2001[ix])
print labels
print sizes
print len(labels)
# Out:
# ['Haryana', 'Punjab', 'Goa', 'Chhattisgarh', 'Kerala', 'Bihar', 'Assam', 'Chandigarh', 'Jharkhand', 'Meghalaya', 'Daman & Diu', 'Madhya Pradesh', 'Lakshadweep', 'Manipur', 'Rajasthan', 'D & N Haveli', 'A & N Islands', 'West Bengal', 'Andhra Pradesh', 'Uttar Pradesh', 'Himachal Pradesh', 'Nagaland', 'Gujarat', 'Tamil Nadu', 'Arunachal Pradesh', 'Maharashtra', 'Tripura', 'Uttarakhand', 'Puducherry', 'Karnataka', 'Jammu & Kashmir', 'Mizoram', 'Delhi (Ut)', 'Odisha', 'Sikkim']
# [6373, 1808, 1375, 4987, 36439, 4334, 1806, 493, 995, 161, 35, 19712, 6, 410, 19999, 87, 181, 11430, 27188, 17921, 2110, 60, 19808, 51978, 236, 37269, 544, 1003, 1286, 32860, 5011, 72, 9282, 6406, 55]
# 35

# %%
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)  
plt.tight_layout()
plt.show()

# %%
#okay so it looks too messy!!
#and is not really giving us much information
#so lets incoperate the population of the state with them (as on 2012)

labels = []
sizes = []
for ix in year_2012:
    labels.append(ix)
    sizes.append(year_2012[ix])
print labels
print sizes
print len(labels)
# Out:
# ['Haryana', 'Punjab', 'Goa', 'Chhattisgarh', 'Kerala', 'Bihar', 'Assam', 'Chandigarh', 'Jharkhand', 'Meghalaya', 'Daman & Diu', 'Madhya Pradesh', 'Lakshadweep', 'Manipur', 'Rajasthan', 'D & N Haveli', 'A & N Islands', 'West Bengal', 'Andhra Pradesh', 'Uttar Pradesh', 'Himachal Pradesh', 'Nagaland', 'Gujarat', 'Tamil Nadu', 'Arunachal Pradesh', 'Maharashtra', 'Tripura', 'Uttarakhand', 'Puducherry', 'Karnataka', 'Jammu & Kashmir', 'Mizoram', 'Delhi (Ut)', 'Odisha', 'Sikkim']
# [9971, 6328, 4288, 13511, 36174, 10320, 6535, 412, 4625, 355, 50, 29173, 0, 771, 22969, 85, 236, 15608, 39344, 24478, 2899, 42, 27267, 67757, 204, 45247, 888, 1455, 1510, 44448, 6637, 110, 6937, 9285, 123]
# 35

# %%
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)  
plt.tight_layout()
plt.show()

# %%
Sikkim = 0.0619
Arunachal_Pradesh = 0.126
Assam = 3.09
Jharkhand = 3.19
Goa = 0.182
Uttar_Pradesh = 20.42
Odisha = 4.6
Tripura = 0.366
Meghalaya = 0.265
Nagaland = 0.228
Manipur = 0.272
Bihar = 9.9
Mizoram = 0.112
Haryana = 2.54
Himachal = 0.686
Telangana =  3.52
Karnataka = 6.41
Uttrakhand = 1.01
Maharashtra = 11.42
Rajasthan = 6.89
Punjab = 2.8
Tamil_Nadu = 6.79
West_Bengal = 9.03
Delhi = 1.9
Kerela = 3.48
Chattisgarh = 2.55
Madhya_Pradesh = 7.33
Jammu = 1.25
Gujarat = 6.27
Andhra_Pradesh = 4.97
Chandigarh = 0.106
Daman = 0.0243
Lakshadweep = 0.0064
DnN = 0.0343
AnN = 0.0381
Puducherry = 0.0654
print len(labels)
# Out:
# 35

# %%
sizes[0] = sizes[0]/haryana
sizes[1] = sizes[1]/Punjab
sizes[2] = sizes[2]/Goa
sizes[3] = sizes[3]/Chattisgarh
sizes[4] = sizes[4]/Kerela
sizes[5] = sizes[5]/Bihar
sizes[6] = sizes[6]/Assam
sizes[7] = sizes[7]/Chandigarh
sizes[8] = sizes[8]/Jharkhand
sizes[9] = sizes[9]/Meghalaya
sizes[10] = sizes[10]/Daman
sizes[11] = sizes[11]/Madhya_Pradesh
sizes[12] = sizes[12]/Lakshadweep
sizes[13] = sizes[13]/Manipur
sizes[14] = sizes[14]/Rajasthan
sizes[15] = sizes[15]/DnN
sizes[16] = sizes[16]/AnN
sizes[17] = sizes[17]/West_Bengal
sizes[18] = sizes[18]/Andhra_Pradesh
sizes[19] = sizes[19]/Uttar_Pradesh
sizes[21] = sizes[21]/Nagaland
sizes[22] = sizes[22]/Gujarat
sizes[23] = sizes[23]/Tamil_Nadu
sizes[24] = sizes[24]/Arunachal_Pradesh
sizes[25] = sizes[25]/Maharashtra
sizes[26] = sizes[26]/Tripura
sizes[27] = sizes[27]/Uttrakhand
sizes[28] = sizes[28]/Puducherry
sizes[29] = sizes[29]/Karnataka
sizes[30] = sizes[30]/Jammu
sizes[31] = sizes[31]/Mizoram
sizes[32] = sizes[32]/Delhi
sizes[33] = sizes[33]/Odisha
sizes[34] = sizes[34]/Sikkim
sizes[20] = sizes[20]/Himachal

# %%
num = 0
for ix in sizes:
    print num," ",ix
    num = num+1
# Out:
# 0   3925.59055118
# 1   2260.0
# 2   23560.4395604
# 3   5298.43137255
# 4   10394.8275862
# 5   1042.42424242
# 6   2114.88673139
# 7   3886.79245283
# 8   1449.84326019
# 9   1339.62264151
# 10   2057.61316872
# 11   3979.94542974
# 12   0.0
# 13   2834.55882353
# 14   3333.67198839
# 15   2478.13411079
# 16   6194.22572178
# 17   1728.4606866
# 18   7916.29778672
# 19   1198.72673849
# 20   4225.94752187
# 21   184.210526316
# 22   4348.80382775
# 23   9978.93961708
# 24   1619.04761905
# 25   3962.08406305
# 26   2426.2295082
# 27   1440.59405941
# 28   23088.6850153
# 29   6934.16536661
# 30   5309.6
# 31   982.142857143
# 32   3651.05263158
# 33   2018.47826087
# 34   1987.07592892

# %%
#considering population

explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)  
plt.tight_layout()
plt.show()

# %%
# we can also consider with respect to area!

# %%
# now we will do one by one analysis of these "accident prone states"
# kerela,tamil
goa_data = []
goa_data.append(year_2001['Goa'])
goa_data.append(year_2002['Goa'])
goa_data.append(year_2003['Goa'])
goa_data.append(year_2004['Goa'])
goa_data.append(year_2005['Goa'])
goa_data.append(year_2006['Goa'])
goa_data.append(year_2007['Goa'])
goa_data.append(year_2008['Goa'])
goa_data.append(year_2009['Goa'])
goa_data.append(year_2010['Goa'])
goa_data.append(year_2011['Goa'])
goa_data.append(year_2012['Goa'])
goa_data.append(year_2013['Goa'])
goa_data.append(year_2014['Goa'])

delhi_data = []
delhi_data.append(year_2001['Delhi (Ut)'])
delhi_data.append(year_2002['Delhi (Ut)'])
delhi_data.append(year_2003['Delhi (Ut)'])
delhi_data.append(year_2004['Delhi (Ut)'])
delhi_data.append(year_2005['Delhi (Ut)'])
delhi_data.append(year_2006['Delhi (Ut)'])
delhi_data.append(year_2007['Delhi (Ut)'])
delhi_data.append(year_2008['Delhi (Ut)'])
delhi_data.append(year_2009['Delhi (Ut)'])
delhi_data.append(year_2010['Delhi (Ut)'])
delhi_data.append(year_2011['Delhi (Ut)'])
delhi_data.append(year_2012['Delhi (Ut)'])
delhi_data.append(year_2013['Delhi (Ut)'])
# delhi_data.append(year_2014['Delhi (Ut)'])

kerela_data = []
kerela_data.append(year_2001['Kerala'])
kerela_data.append(year_2002['Kerala'])
kerela_data.append(year_2003['Kerala'])
kerela_data.append(year_2004['Kerala'])
kerela_data.append(year_2005['Kerala'])
kerela_data.append(year_2006['Kerala'])
kerela_data.append(year_2007['Kerala'])
kerela_data.append(year_2008['Kerala'])
kerela_data.append(year_2009['Kerala'])
kerela_data.append(year_2010['Kerala'])
kerela_data.append(year_2011['Kerala'])
kerela_data.append(year_2012['Kerala'])
kerela_data.append(year_2013['Kerala'])
kerela_data.append(year_2014['Kerala'])

tamil_data = []
tamil_data.append(year_2001['Tamil Nadu'])
tamil_data.append(year_2002['Tamil Nadu'])
tamil_data.append(year_2003['Tamil Nadu'])
tamil_data.append(year_2004['Tamil Nadu'])
tamil_data.append(year_2005['Tamil Nadu'])
tamil_data.append(year_2006['Tamil Nadu'])
tamil_data.append(year_2007['Tamil Nadu'])
tamil_data.append(year_2008['Tamil Nadu'])
tamil_data.append(year_2009['Tamil Nadu'])
tamil_data.append(year_2010['Tamil Nadu'])
tamil_data.append(year_2011['Tamil Nadu'])
tamil_data.append(year_2012['Tamil Nadu'])
tamil_data.append(year_2013['Tamil Nadu'])
tamil_data.append(year_2014['Tamil Nadu'])

# %%
print year_2014['Delhi Ut']
delhi_data.append(8310)
# Out:
# 8310

# %%
num = 1
for ix in goa_data:
    print num," ",ix
    num=num+1
num = 1
for ix in delhi_data:
    print num," ",ix
    num=num+1
num = 1
for ix in kerela_data:
    print num," ",ix
    num=num+1
# Out:
# 1   1375
# 2   1201
# 3   1678
# 4   1542
# 5   1069
# 6   3749
# 7   4022
# 8   4179
# 9   4170
# 10   4574
# 11   4561
# 12   4288
# 13   4293
# 14   4230
# 1   9282
# 2   8710
# 3   8869
# 4   9110
# 5   9580
# 6   9699
# 7   10528
# 8   8566
# 9   7614
# 10   7220
# 11   7280
# 12   6937
# 13   7569
# 14   8310
# 1   36439
# 2   34534
# 3   31947
# 4   41103
# 5   42295
# 6   41728
# 7   39861
# 8   37238
# 9   35457
# 10   35082
# 11   35216
# 12   36174
# 13   35215
# 14   35872

# %%
print len(delhi_data)
# Out:
# 14

# %%
x_axis_val = [2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014]
plt.xlabel("Year")
plt.ylabel("number of accidents")
plt.plot(x_axis_val,goa_data)
plt.plot(x_axis_val,delhi_data,'--')
plt.plot(x_axis_val,kerela_data,'*')
plt.plot(x_axis_val,tamil_data)
plt.show()

# %%
#now evaluation with respect to months
print df.shape
print df[0][0],df[0][1],df[0][2]
# Out:
# (490, 15)
# A & N Islands 2001 8

# %%
jan = 0
feb = 0
march = 0
april = 0
may = 0
june = 0
july = 0
aug = 0
sept = 0
octo = 0
nov = 0
dec = 0

for ix in range(df.shape[0]):
    jan = jan + df[ix][2]
    feb = feb + df[ix][3]
    march = march +df[ix][4]
    april = april + df[ix][5]
    may = may + df[ix][6]
    june = june + df[ix][7]
    july = july + df[ix][8]
    aug = aug + df[ix][9]
    sept = sept + df[ix][10]
    octo = octo + df[ix][11]
    nov = nov + df[ix][12]
    dec = dec + df[ix][13]
print jan
print feb
print march
print april
print may
print june
print july
print aug
print sept
print octo
print nov
print dec
# Out:
# 482719
# 459272
# 486141
# 479663
# 521563
# 473574
# 440263
# 438351
# 435302
# 454961
# 457192
# 473905

# %%
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)

labels = ['jan','feb','march','april','may','june','july','aug','sept','oct','nov','dec']
sizes = [jan,feb,march,april,may,june,july,aug,sept,octo,nov,dec]
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)  
plt.tight_layout()
plt.show()

# %%
#slightly more in may.. because of rain probably!
